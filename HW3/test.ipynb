# %%
# !pip install torch==2.1.0
# !pip install transformers==4.34.1
# !pip install bitsandbytes
# !pip install peft==0.6.0
# !pip install datasets
# !pip install evaluate
# !pip install accelerate
# !pip install sentencepiece
# !pip install einops
# !pip install scikit-learn
# !pip install ipdb

# %%
from collections import defaultdict
import copy
import json
import os
from os.path import exists, join, isdir
from dataclasses import dataclass, field
import sys
from typing import Optional, Dict, Sequence
import numpy as np
from tqdm import tqdm
import logging
import bitsandbytes as bnb
import pandas as pd
import importlib

import torch
import transformers
from torch.nn.utils.rnn import pad_sequence
import argparse
from transformers import (
    set_seed,
    AutoTokenizer,
    AutoConfig,
    AutoModelForCausalLM,
    Seq2SeqTrainer,
    BitsAndBytesConfig,
    LlamaTokenizer

)
from datasets import load_dataset, Dataset
from peft import (
    prepare_model_for_kbit_training,
    LoraConfig,
    get_peft_model,
    PeftModel
)
from peft.tuners.lora import LoraLayer
from transformers.trainer_utils import PREFIX_CHECKPOINT_DIR

from accelerate import notebook_launcher
from accelerate import Accelerator
from utils import get_bnb_config
from utils import get_prompt
from torch.utils.data import DataLoader

# %%
# Global variables
FROM_COLAB = False
DEBUG = False
ROOT_PATH = './'
str_args = None

# %%
if FROM_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    ROOT_PATH = 'drive/MyDrive/Colab Notebooks/ADL/HW3/'
if DEBUG:
    import ipdb

# %%
# Comment out when using .py file
str_args = [
    "--test_file", ROOT_PATH + "data/public_test.json",
    "--model_name_or_path", ROOT_PATH + "Taiwan-LLM-7B-v2.0-chat",
    "--peft_model", ROOT_PATH + "output/checkpoint-200",
    "--output_path", "./t/prediction.json"
]

# %%
# Parser
def parse_args(str_args = None):
    parser = argparse.ArgumentParser()
    # Data
    parser.add_argument("--seed", type=int, default=None)
    parser.add_argument("--test_file", type=str ,required=True)
    parser.add_argument(
        "--output_path",
        type=str,
        default="./prediction.json"
    )
    parser.add_argument(
        "--model_name_or_path",
        type=str,
        default = None
    )
    parser.add_argument(
        "--peft_model",
        type=str,
        default = None
    )
    # Trainer Parameters
    parser.add_argument(
        "--batch_size",
        type=int,
        default=2,
    )
    parser.add_argument(
        "--source_max_len",
        type=int,
        default=1024,
    )
    # Generation Argument
    parser.add_argument(
        "--max_new_tokens",
        type=int,
        default=256
    )
    parser.add_argument(
        "--min_new_tokens",
        type=int,
        default=None
    )
    parser.add_argument(
        "--do_sample",
        action='store_true'
    )
    parser.add_argument(
        "--num_beams",
        type=int,
        default=1
    )
    parser.add_argument(
        "--num_beam_groups",
        type=int,
        default=1
    )

    args = parser.parse_args(str_args)
    return args

# %%
@dataclass
class DataCollatorForCausalLM(object):
    tokenizer: transformers.PreTrainedTokenizer
    source_max_len: int

    def __call__(self, instances: Sequence[Dict]) -> Dict[str, torch.Tensor]:
        # Extract elements
        IGNORE_INDEX = -100
        sources = [f"{self.tokenizer.bos_token}{example['input']}" for example in instances]
        # Tokenize
        tokenized_sources_with_prompt = self.tokenizer(
            sources,
            max_length=self.source_max_len,
            truncation=True,
            add_special_tokens=False,
        )
        # Build the input for causal LM
        input_ids = []
        for tokenized_source in tokenized_sources_with_prompt['input_ids']:
                input_ids.append(torch.tensor(tokenized_source))
        # Apply padding
        input_ids = pad_sequence(input_ids, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        data_dict = {
            'input_ids': input_ids,
            'attention_mask':input_ids.ne(self.tokenizer.pad_token_id),
        }
        return data_dict

# %%
def main(str_args = None):
    args = parse_args(str_args)

args = parse_args(str_args)

# %%
# Prepare
logger = logging.getLogger(__name__)
compute_dtype = torch.float16
if args.seed is not None:
    set_seed(args.seed)
if args.output_path is not None:
    output_dir = os.path.join(*args.output_path.split("/")[:-1])
    os.makedirs(output_dir, exist_ok=True)

# %%
# Load dataset
print('Load Dataset')
def format_dataset(dataset):
    def processing(example):
        return {'input': get_prompt(example['instruction'])}
    dataset = dataset.map(processing, remove_columns=['instruction','output'])
    return dataset

raw_dataset = load_dataset("json", data_files=args.test_file,split='train')
test_dataset = format_dataset(raw_dataset)
# Out:
# Load Dataset
# Map: 100%|██████████| 250/250 [00:00<00:00, 15334.99 examples/s]

# %%
# Load Model
print('Load Model')
bnb_config = get_bnb_config()
base_model = AutoModelForCausalLM.from_pretrained(
    args.model_name_or_path,
    quantization_config = bnb_config,
    load_in_4bit = True,
    torch_dtype=compute_dtype,
    device_map = 'cuda:0'
)
base_model.config.torch_dtype=compute_dtype
# Load PeftModel
print("Loading adapters.")
model = PeftModel.from_pretrained(base_model, args.peft_model)
# Out:
# Load Model
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.59s/it]
# Loading adapters.

# %%
# Load Tokenizer
print('Load Tokenizer')
tokenizer = AutoTokenizer.from_pretrained(
    args.model_name_or_path,
    padding_side="right",
    use_fast=False,
    tokenizer_type='llama'
)
tokenizer.add_special_tokens({
    "eos_token": tokenizer.convert_ids_to_tokens(base_model.config.eos_token_id),
    "bos_token": tokenizer.convert_ids_to_tokens(base_model.config.bos_token_id),
    "unk_token": tokenizer.convert_ids_to_tokens(tokenizer.pad_token_id),
})
# Out:
# Load Tokenizer
# 0

# %%
# Data Collator
data_collator = DataCollatorForCausalLM(
    tokenizer=tokenizer,
    source_max_len=args.source_max_len
)
# Generatrion Config
gen_config = transformers.GenerationConfig(
    max_new_tokens = args.max_new_tokens,
    min_new_tokens = args.min_new_tokens,
    do_sample = args.do_sample,
    num_beams = args.num_beams,
    num_beam_groups = args.num_beam_groups,
    )

# %%
test_dataloader = DataLoader(test_dataset, collate_fn=data_collator, batch_size=args.batch_size)
progress = tqdm(total=len(test_dataloader))
model.eval()
all_predictions=[]
for step, batch in enumerate(test_dataloader):
    with torch.no_grad():
        predictions = model.generate(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            generation_config = gen_config,
        )
        predictions = np.where(predictions != -100, predictions, tokenizer.pad_token_id)
        predictions = tokenizer.batch_decode(
            predictions, skip_special_tokens=True, clean_up_tokenization_spaces=True
        )
        all_predictions.append(predictions)
        progress.update()
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]/home/vr/anaconda3/envs/adl-hw3-copy/lib/python3.10/site-packages/transformers/generation/utils.py:1539: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# 100%|██████████| 125/125 [12:39<00:00,  5.99s/it]

# %%
all_predictions
# Out:
# [['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n於是，廢帝讓瀋慶之的堂侄、直將軍瀋攸之賜瀋慶之毒藥，命瀋慶之自殺。 ASSISTANT: 乃廢帝賜瀋慶之毒藥，命瀋慶之自殺。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 文言文翻譯：\n靈鑒忽臨，忻歡交集，乃迴燈拂席以延之。 ASSISTANT: 答案：靈鑒忽然臨歡，忻歡與他交換瞭燈火，於是將燈火延長到席上。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 希望您以後留意，不要再齣這樣的事，你的小女兒病就會好。\n這句話在古代怎麼說： ASSISTANT: 願您以後留意，不要再齣這樣的事，您的小女兒病就會好。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 第二年召迴朝廷，改任著作佐郎，直史館，改任左拾遺。\n翻譯成文言文： ASSISTANT:Љ 二年召迴，改任著作佐郎直史館，改任左拾遺。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 文言文翻譯：\n中宗與庶人嘗因正月十五日夜幸其第，賜賚不可勝數。 ASSISTANT: 答案：中宗與庶人們因為正月十五日晚上去他的宅邸賜賞不可勝數。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n硃全忠聽後哈哈大笑。 ASSISTANT: 硃全忠聞後大笑。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 從唐末幽、薊二州割據以來，戍守的軍隊廢置散失，契丹因而得以齣來攻陷平、營二州，而幽、薊二州的人每年深受契丹侵犯掠奪之苦。\n這句話在中國古代怎麼說： ASSISTANT:Љ 從唐末幽、薊二州割據以來，戍守的軍隊廢置散失，契丹因而得以齣來攻陷平、營二州，而幽、薊二州的人每年深受契丹侵犯掠奪之苦。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 建武帝蕭鸞繼位做皇帝，沿襲陳舊的一套做法，當時流行風氣不好文學，輔臣宰相沒有學識，學校雖然設置瞭，先前行事規範再也難找，劉鍬承繼馬融、鄯玄之後，一個時期學生門徒把他看作是師長楷模。\n翻譯成文言文： ASSISTANT: 建武帝鸞繼即帝位，繼舊一套，時風氣不好，臣宰相無學，學校設，先前行事規範難找，鍬承馬融、鄯玄，一時門徒為師長楷模。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 文言文翻譯：\n契丹主以陽城之戰為彥卿所敗，詰之。彥卿曰： 臣當時惟知為晉主竭力，今日死生惟命。 ASSISTANT:\n答案：契丹主以陽城之戰為彥卿所敗，詰問他。彥卿說： 我當時只知道為晉主竭力，現在死活都是為晉主所決定。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 秦領是都人，從江夏都尉升任南陽太守，上任時經過宜城城內，看見一傢朝東的房子，他停車觀看，說：這個住人的地方可以築墓。\n翻譯成文言文： ASSISTANT: 秦領是都人，從江夏都尉升南陽，上任時經宜城城內，見一傢朝東的房子，停車觀之，謂之可築墓。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n泰始四年正月丁亥日，皇帝親自耕種責任田。 ASSISTANT: 泰始四年正月丁亥，詔耕種責任田。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER:
',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 今秦王二子，母皆罪廢，不閤承嗣。\n翻譯成現代文： ASSISTANT: 今天秦國的兩個王子，母親都被廢罪，不讓他們繼承王位。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成現代文：\n龜年丐祠，慶元二年，以呂棐言落職；已而追三官，勒停。 ASSISTANT: 龜年，呂棐說： 我沒有做錯事，為什麼要落職？ 於是恢復他的官職，又將他調到另一個地方。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n免除本年租賦、丁口力役一半。 ASSISTANT: 免本年租賦、丁口力役一半。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n於是釋免瞭特母哥。 ASSISTANT: 即釋免特母哥。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n要使百姓改變看法，用以實現廣遠深入的教化，達到沒有人犯法的美好境界，並無窮無盡地流傳下去。\n答案： ASSISTANT: 以變化百姓，實行廣遠深入之教化，達無犯法之美，流傳無窮無盡。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n但皇上對溫造的舉奏，依然盡皆聽納。 ASSISTANT: 而帝對溫造之舉，皆聽之。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 詔仁軌檢校帶方州刺史，統文度之眾，並發新羅兵為援，仁軌將兵嚴整，轉鬥陷陣，所嚮無前。\n把這句話翻譯成現代文。 ASSISTANT: 皇上詔令仁軌檢校帶方州刺史，統率文度之眾，並發新羅兵為援，仁軌將兵嚴整，轉鬥陷陣，所嚮無前。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 僅僅是供養兒女吃穿，而不好好教育，是父親的過錯。\n翻譯成文言文： ASSISTANT:Љ 僅供養兒女食穿，而不好好教育，是父之過錯。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 至此獻、昭、乾、定、泰五個陵寢各造屋三百八十間，元、橋、建三座陵寢據缺少情況補造。五月一日是朔日。\n幫我把這句話翻譯成文言文 ASSISTANT: 至此獻、昭、乾、定、泰五個陵寢各造屋三百八十間，元、橋、建三座陵寢據缺少情況補造。五月一日是朔日。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n通達天下之誌的衹有忠，裁定天下的疑難衹有文，切閤天下之情的衹有遠，彌閤天下的事情衹有大，變化無常態的衹有理，如果不是天下的聖賢，誰能夠參與這些事情! ASSISTANT: 通達天下之誌者，衹有忠，裁定天下之疑難者，衹有文，切閤天下之情者，衹有遠，彌閤天下之事者，衹有大，變化無常態者，衹有理，誰能參與之！',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n癸未，有黑氣如龍，齣現在宮殿裹。\n答案： ASSISTANT: 癸未，有黑氣如龍，齣宮殿裹。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n孫策曾進攻祖郎，被敵軍層層包圍，程普同一名騎兵一起掩護孫策，策馬高喊，用長矛刺殺敵人，敵人往兩邊分開，孫策趁機跟隨程普衝齣重圍。 ASSISTANT: 策曾攻祖郎，層層圍之，普同騎兵掩之，策馬高呼，長矛刺之，敵齣兩邊，策趁之齣圍。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 當在宋國的時候，我準備遠行，對遠行的人理應送些盤纏。\n翻譯成古文： ASSISTANT: 宋之時，欲遠行，對遠行者應盤纏之。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 惟汝諧。\n翻譯成現代文： ASSISTANT: 唯有您說。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 文言文翻譯：\n病者搖首曰： 費亦太過，願死而已。 ASSISTANT: 答案：病人搖頭說： 我也太過分，願意死而已。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n硃熹極力推辭，被任命為秘閣修撰，管理一個外地的宮觀。 ASSISTANT:Љ 硃熹極力推辭，賜為秘閣修撰，管理一個外地宮觀。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯
'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 太常寺上奏： 按禮所規定，婦人不用鼓吹樂。\n翻譯成古文： ASSISTANT: 太常寺上奏： 按禮所規定，婦人不用鼓吹樂。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 河水又往東流經平縣舊城北邊。\n這句話在古代怎麼說： ASSISTANT: 水又東流平縣舊城北。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成現代文：\n若琴徽之姺病矣。 ASSISTANT: 如果琴徽的姊姊病倒瞭。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 郭子儀三次上錶章請求辭讓尚書令，詞語懇切，皇上十分體諒，下詔書聽從瞭他的請求。\n這句話在中國古代怎麼說： ASSISTANT: 子儀三錶請辭尚書令，詞懇，帝體之。詔聽之。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 身長八尺二寸，姿望秀偉，飲酒石餘，而遲鈍質樸，不為鄉親所重。\n幫我把這句話翻譯成現代文 ASSISTANT:Љ身長八尺二寸，姿態優雅，飲酒石餘，而遲鈍質樸，不為鄉親所重。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成文言文：\n於是殷浩放棄瞭處死蔡謨的打算，下達詔書將其免官並貶為庶人。 ASSISTANT: 於是殷浩棄之，詔免謨，貶為庶人。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成現代文：\n爵投牒直之，並係。\n答案： ASSISTANT: 翻譯成現代文：\n爵投牒直之，並係。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 濛豫敕四將，各選百人，普齣，便入守城門。\n把這句話翻譯成現代文。 ASSISTANT: 濛豫下旨，派遣四將，各選百人，普齣，便入城。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 三月，甘美的雨露降在南郡的桐樹上。\n把這句話翻譯成文言文： ASSISTANT:Љ 三月，甘美雨露降桐於南郡。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 微自乞老病求歸，亮又與書答曰： 曹丕篡弑，自立為帝，是猶土龍芻狗之有名也。\n翻譯成現代文： ASSISTANT: 曹丕篡奪曹叡的政權，自己即位為皇帝，這是猶如土龍芻狗的有名案例。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 及守澄入知樞密，挈注以西，為立居宅，贍給之。\n把這句話翻譯成現代文。 ASSISTANT: 到守澄進入知樞密，挑選以西的地方為他的住所，並且給予他禦職。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成現代文：\n江陵陷，周武帝尤重之，授太學博士。\n答案： ASSISTANT: 江陵失陷，周武帝對他特別重視，任命他為太學博士。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯成文言文：\n當時華歆擔任豫章太守，嚮來和鄭泰關係很好，鄭渾就渡過長江投靠華歆。\n答案： ASSISTANT:Љ 時華歆為豫章太守，嚮來與鄭泰交好，鄭渾即渡長江歸華歆。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 到三月初一，世宗纔給禮官發布詔令，加稱興獻帝為本生皇考恭穆獻皇帝，興國太後為本生母章聖皇太後，讓選擇日期到郊廟祭告，並頒布詔書，通告天下，又另外指示在奉先殿一側修建世室，以便恭敬地祭祀獻皇。\n翻譯成文言文： ASSISTANT: 至三月初一，世宗終發詔書，加興獻帝為本生皇考恭穆獻皇帝，興國太後為本生母章聖皇太後，讓選擇日期到郊廟祭告，並頒詔書通告天下，另指定在奉先殿一側修建世室，以便恭敬地祭獻皇。'],
#  ['你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 將下麵句子翻譯成現代文：\n辛醜，籍阿閤馬妻子婿奴婢財産。 ASSISTANT: 辛醜，籍阿閤的妻子婿奴婢財産。',
#   '你是人工智慧助理，以下是用戶和人工智能助理之間的對話。你要對用戶的問題提供有用、安全、詳細和禮貌的回答。USER: 翻譯